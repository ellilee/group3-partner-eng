# %% [markdown]
# # Retail Properties: Data Cleaning + EDA

# %% [markdown]
# In this notebook, we will be examining the raw dataset (pca_retail_building_section_1&4&5.csv), cleaning the data, and performing exploratory data analysis.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Examining the Raw Dataset

# %% [markdown]
# Importing the raw dataset and identifying NA values and inconsistencies.

# %%
# Importing libraries for EDA
import pandas as pd

# Read in raw dataset
retail = pd.read_csv('pca_retail_building_section_1&4&5_data_items.csv')

# %% [markdown]
# ### Displaying RETAIL Data Overview

# %%
# Display RETAIL Data Overview
retail.head(50)
# Out:
#           id  project_id                                   document_spot  \
# 0   64098211      621709                                      541b_wall1
# 1   64099519      621709                                        542a_esc
# 2   64099836      621709                               551_fire_hydrants
# 3   64102647      621709                               pca_reserve_yn_8a
# 4   64070020      623951                                553b_othrsysdesc
# 5   64099948      621709                               552_smoke_det_loc
# 6   64099832      621709                               551p_fire_ex_cond
# 7   64098144      621709                                     53m_stablok
# 8   64095621      621709                              pca_reserve_yn_36a
# 9   64098089      621709                                      53a_transf
# 10  64103592      621709                               1zp_build_address
# 11  64100043      621709                          431dd_facade_ordinance
# 12  63983352      621170                                  01q_client_zip
# 13  64099874      621709                                     552b_detloc
# 14  64099864      621709                                   552aa_fa_comp
# 15  64100127      621709                              pca_reserve_yn_65a
# 16  64103635      621709                                1i_eul_statement
# 17  64100141      621709                                      451_1f_pca
# 18  64100049      621709                                       432a_wind
# 19  64103574      621709                                  pca_01_eff_age
# 20  64103653      621709                                     45h_fbscond
# 21  64099534      621709                                      551a_fsupp
# 22  64098228      621709                                  541aa_elevcond
# 23  64103637      621709                    1m_additional_investigations
# 24  64099541      621709                                  551b_fsuppserv
# 25  64097384      621709                                      51a_domrep
# 26  64097937      621709                              pca_reserve_yn_23a
# 27  64097622      621709                                     51ba_whcond
# 28  64103651      621709                              pca_reserve_yn_19a
# 29  64098133      621709                    53_unit_individually_metered
# 30  64098150      621709                                       53_4a_pca
# 31  64100134      621709                              pca_reserve_yn_66a
# 32  64100071      621709                                433dp_oh_door_op
# 33  63983351      621170                                01p_client_state
# 34  64103647      621709                                      442a_drain
# 35  64100169      621709                                    45g_balcrail
# 36  64099857      621709                                      552_1a_pca
# 37  64099809      621709                                      551_1b_pca
# 38  64097383      621709                                   51b_dompipobs
# 39  64100162      621709                                     45f_balctyp
# 40  64098206      621709                        elevator_manufacture_541
# 41  64097880      621709                                      52a_1b_pca
# 42  64099522      621709                                        542b_esc
# 43  64099804      621709                                   551h_suppinsp
# 44  64102615      621709                              pca_reserve_yn_50a
# 45  63983341      621170                                01c_project_city
# 46  64098111      621709  amperage_supplied_to_main_switchgearpanel_53sb
# 47  64100051      621709                                   432c_windcond
# 48  64100076      621709                              pca_reserve_yn_17a
# 49  64099986      621709                                   42b_horzconst
#
#                                          outside_name  \
# 0                                          541b_wall1
# 1                          are_escalators_present_542
# 2                                   551_fire_hydrants
# 3                                   pca_reserve_yn_8a
# 4                       other_systems_description_553
# 5                                   552_smoke_det_loc
# 6                                   551p_fire_ex_cond
# 7                 federal_pacific_stab_lok_present_53
# 8                                  pca_reserve_yn_36a
# 9   transformers_main_electrical_service_delivery_...
# 10                                  1zp_build_address
# 11                             431dd_facade_ordinance
# 12                                     01q_client_zip
# 13          where_are_the_smoke_detectors_located_552
# 14                                      552aa_fa_comp
# 15                                 pca_reserve_yn_65a
# 16                                   1i_eul_statement
# 17                                         451_1f_pca
# 18                                        windows_432
# 19                                                NaN
# 20  exterior_stair_fire_escape_andor_balcony_condi...
# 21     is_there_a_fire_suppression_system_present_551
# 22                              elevator_condition_54
# 23                       1m_additional_investigations
# 24                                   areas_served_551
# 25                  reported_domestic_water_piping_51
# 26                                 pca_reserve_yn_23a
# 27                  water_heating_system_condition_51
# 28                                 pca_reserve_yn_19a
# 29                   53_unit_individually_metered\r\n
# 30                                          53_4a_pca
# 31                                 pca_reserve_yn_66a
# 32                                   433dp_oh_door_op
# 33                                   01p_client_state
# 34                                  roof_drainage_442
# 35                                 balcony_railing_45
# 36                                         552_1a_pca
# 37                                         551_1b_pca
# 38                  observed_domestic_water_piping_51
# 39                                    balcony_type_45
# 40                           elevator_manufacture_541
# 41                                         52a_1b_pca
# 42                      area_served_by_escalators_542
# 43        fire_suppression_system_inspection_date_551
# 44                                 pca_reserve_yn_50a
# 45                                   01c_project_city
# 46     amperage_supplied_to_main_switchgearpanel_53sb
# 47                               window_condition_433
# 48                                 pca_reserve_yn_17a
# 49                   building_structure_horizontal_42
#
#                                              the_data  \
# 0                                           ["Metal"]
# 1                                                 yes
# 2                                                 yes
# 3                                                  no
# 4   Emergency lighting was typically provided by c...
# 5                        each commercial tenant space
# 6                                                Good
# 7                                                  no
# 8                                                  no
# 9                              Pad-mounted - Multiple
# 10                                                 no
# 11               Not applicable - no façade ordinance
# 12                                              92614
# 13                       each commercial tenant space
# 14  ["Sprinkler flow and tamper switches", "Smoke ...
# 15                                                 no
# 16                                                yes
# 17                                               none
# 18                    ["Storefront with entry doors"]
# 19                                                 12
# 20                                               Good
# 21                                                yes
# 22                                               Good
# 23                                                 no
# 24  The wet-pipe sprinkler system are provided fir...
# 25                                         ["Copper"]
# 26                                                 no
# 27                    Good - Reserve Cost Anticipated
# 28                                                 no
# 29                                               none
# 30                                                 no
# 31                                                 no
# 32                               ["Electric openers"]
# 33                                         California
# 34                 ["Roof Drains & Interior Leaders"]
# 35                                       ["Concrete"]
# 36                                                 no
# 37                                                 no
# 38                                         ["Copper"]
# 39                  ["Cantilever", "Column Supports"]
# 40                                               Kone
# 41                                                 no
# 42  The escalators observed in central courtyards ...
# 43                                on November 1, 2023
# 44                                                 no
# 45                                      San Francisco
# 46                                            120/208
# 47                                               Good
# 48                                                 no
# 49       ["Open-web steel joists with steel decking"]
#
#                                         document_text section_reference  \
# 0                                 metal wall finishes             5.4.1
# 1                                                 NaN             5.4.2
# 2                                                 NaN             5.5.1
# 3                                                 NaN               1.0
# 4   Emergency lighting was typically provided by c...             5.5.3
# 5   Smoke detectors were located in each commercia...             5.5.2
# 6   The fire extinguishers appeared to be in good ...             5.5.1
# 7   Federal Pacific Electric (FPE) Stab-Lok circui...               5.3
# 8                                                 NaN               1.0
# 9   Electrical service was provided via several pa...               5.3
# 10                                                NaN               1.0
# 11                                                NaN             4.3.1
# 12                                              92614                 1
# 13  Smoke detectors were located in each commercia...             5.5.2
# 14  The fire alarm system was reportedly comprised...             5.5.2
# 15                                                NaN             4.4.1
# 16  Unless noted otherwise, the subject property a...               1.0
# 17                                                NaN               4.5
# 18  Windows appeared to be part of a storefront wi...             4.3.2
# 19                                                NaN               1.0
# 20  Stairs appeared to be in good condition. Routi...               4.5
# 21                                                NaN             5.5.1
# 22        Elevators appeared to be in good condition.             5.4.2
# 23  There were no issues observed or reported that...                 1
# 24  The wet-pipe sprinkler system are provided fir...             5.5.1
# 25    Domestic water piping was reported to be copper               5.1
# 26                                                NaN               1.0
# 27  The water heating equipment appeared to be in ...               5.1
# 28                                                NaN               1.0
# 29                                                NaN               5.3
# 30                                                NaN               5.3
# 31                                                NaN             4.4.1
# 32          that were operated with electric openers.             4.3.3
# 33                                         California                 1
# 34  Storm water runoff for the roof was directed t...             4.4.2
# 35                    Balcony railings were concrete.               4.5
# 36                                                NaN             5.5.2
# 37                                                NaN             5.5.1
# 38  Observation of visible piping at plumbing stub...               5.1
# 39  Elevated public walkways along central courtya...               4.5
# 40                                               Kone             5.4.1
# 41                                                NaN               5.2
# 42  Service area include The escalators observed i...             5.4.2
# 43  The system was reportedly tested on an annual ...             5.5.1
# 44                                                NaN               1.0
# 45                                      San Francisco                 1
# 46       120/208-volt at the main distribution panel.               5.3
# 47  Windows were reported and appeared to be in go...             4.3.2
# 48                                                NaN               1.0
# 49  Upper floors consisted of open-web steel joist...               4.2
#
#                  type
# 0   PcaReportDataItem
# 1   PcaReportDataItem
# 2   PcaReportDataItem
# 3   PcaReportDataItem
# 4   PcaReportDataItem
# 5   PcaReportDataItem
# 6   PcaReportDataItem
# 7   PcaReportDataItem
# 8   PcaReportDataItem
# 9   PcaReportDataItem
# 10  PcaReportDataItem
# 11  PcaReportDataItem
# 12  PcaReportDataItem
# 13  PcaReportDataItem
# 14  PcaReportDataItem
# 15  PcaReportDataItem
# 16  PcaReportDataItem
# 17  PcaReportDataItem
# 18  PcaReportDataItem
# 19  PcaReportDataItem
# 20  PcaReportDataItem
# 21  PcaReportDataItem
# 22  PcaReportDataItem
# 23  PcaReportDataItem
# 24  PcaReportDataItem
# 25  PcaReportDataItem
# 26  PcaReportDataItem
# 27  PcaReportDataItem
# 28  PcaReportDataItem
# 29  PcaReportDataItem
# 30  PcaReportDataItem
# 31  PcaReportDataItem
# 32  PcaReportDataItem
# 33  PcaReportDataItem
# 34  PcaReportDataItem
# 35  PcaReportDataItem
# 36  PcaReportDataItem
# 37  PcaReportDataItem
# 38  PcaReportDataItem
# 39  PcaReportDataItem
# 40  PcaReportDataItem
# 41  PcaReportDataItem
# 42  PcaReportDataItem
# 43  PcaReportDataItem
# 44  PcaReportDataItem
# 45  PcaReportDataItem
# 46  PcaReportDataItem
# 47  PcaReportDataItem
# 48  PcaReportDataItem
# 49  PcaReportDataItem

# %% [markdown]
# ### Initial Observations

# %% [markdown]
# - ~2% of the values are missing in the outside_name column. outside_name represents the variable name that is shown to users on the property assessment report. This may vary in the full dataset as this is only in the first 50 rows we see.

# %% [markdown]
# - We may choose to drop outside_name, but may also not since document_spot may be able to provide the same information.

# %% [markdown]
# - 40% of the values are missing in the column. This is not a worry, as document_text is an optional field for users to input additional information about their property in the reporting process, so we can just ignore these.

# %% [markdown]
# ### Looking at full RETAIL Data

# %%
retail
# Out:
#               id  project_id        document_spot  \
# 0       64098211      621709           541b_wall1
# 1       64099519      621709             542a_esc
# 2       64099836      621709    551_fire_hydrants
# 3       64102647      621709    pca_reserve_yn_8a
# 4       64070020      623951     553b_othrsysdesc
# ...          ...         ...                  ...
# 558412  59679704      609229          53m_stablok
# 558413  59604146      609647      441ap_flash_mat
# 558414  59679944      609229   pca_reserve_yn_13a
# 558415  59679351      609229  01zp_project_county
# 558416  59601970      609647        433ap_oh_door
#
#                                outside_name  \
# 0                                541b_wall1
# 1                are_escalators_present_542
# 2                         551_fire_hydrants
# 3                         pca_reserve_yn_8a
# 4             other_systems_description_553
# ...                                     ...
# 558412  federal_pacific_stab_lok_present_53
# 558413                      441ap_flash_mat
# 558414                   pca_reserve_yn_13a
# 558415                  01zp_project_county
# 558416                        433ap_oh_door
#
#                                                  the_data  \
# 0                                               ["Metal"]
# 1                                                     yes
# 2                                                     yes
# 3                                                      no
# 4       Emergency lighting was typically provided by c...
# ...                                                   ...
# 558412                                               none
# 558413                    ["Similar to roofing membrane"]
# 558414                                                 no
# 558415                                             Sussex
# 558416                            ["Steel panel roll-up"]
#
#                                             document_text section_reference  \
# 0                                     metal wall finishes             5.4.1
# 1                                                     NaN             5.4.2
# 2                                                     NaN             5.5.1
# 3                                                     NaN               1.0
# 4       Emergency lighting was typically provided by c...             5.5.3
# ...                                                   ...               ...
# 558412                                                NaN               5.3
# 558413  Flashing materials appeared to be similar to t...             4.4.1
# 558414                                                NaN               1.0
# 558415                                             Sussex                 1
# 558416  The overhead doors consisted of steel panel ro...             4.3.3
#
#                      type
# 0       PcaReportDataItem
# 1       PcaReportDataItem
# 2       PcaReportDataItem
# 3       PcaReportDataItem
# 4       PcaReportDataItem
# ...                   ...
# 558412  PcaReportDataItem
# 558413  PcaReportDataItem
# 558414  PcaReportDataItem
# 558415  PcaReportDataItem
# 558416  PcaReportDataItem
#
# [558417 rows x 8 columns]

# %% [markdown]
# <hr>

# %% [markdown]
# ## Examining NA Values

# %%
# Counting NA values for all columns
na_count = retail.isna().sum()
print(na_count)
# Out:
# id                        0
# project_id                0
# document_spot             0
# outside_name           3958
# the_data                  0
# document_text        148653
# section_reference         0
# type                      0
# dtype: int64

# %% [markdown]
# There are 3958 rows of missing outside_name data. This is ~0.007% of the full retail data. Because we are going to use document_spot for attributing a row to a specific value for a structural attribute, we can ignore the NA's in outside_name.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Examining Unique Values

# %% [markdown]
# ### Looking at the unique values of document_spot, section_reference

# %% [markdown]
# document_spot is the attribute field as shown in the PCA report

# %% [markdown]
# section_reference is the section that the attribute field is located in the PCA report

# %%
# All of the unique property attributes in our data
retail['document_spot'].unique()
# Out:
# array(['541b_wall1', '542a_esc', '551_fire_hydrants', 'pca_reserve_yn_8a',
#        '553b_othrsysdesc', '552_smoke_det_loc', '551p_fire_ex_cond',
#        '53m_stablok', 'pca_reserve_yn_36a', '53a_transf',
#        '1zp_build_address', '431dd_facade_ordinance', '01q_client_zip',
#        '552b_detloc', '552aa_fa_comp', 'pca_reserve_yn_65a',
#        '1i_eul_statement', '451_1f_pca', '432a_wind', 'pca_01_eff_age',
#        '45h_fbscond', '551a_fsupp', '541aa_elevcond',
#        '1m_additional_investigations', '551b_fsuppserv', '51a_domrep',
#        'pca_reserve_yn_23a', '51ba_whcond', 'pca_reserve_yn_19a',
#        '53_unit_individually_metered', '53_4a_pca', 'pca_reserve_yn_66a',
#        '433dp_oh_door_op', '01p_client_state', '442a_drain',
#        '45g_balcrail', '552_1a_pca', '551_1b_pca', '51b_dompipobs',
#        '45f_balctyp', 'elevator_manufacture_541', '52a_1b_pca',
#        '542b_esc', '551h_suppinsp', 'pca_reserve_yn_50a',
#        '01c_project_city',
#        'amperage_supplied_to_main_switchgearpanel_53sb', '432c_windcond',
#        'pca_reserve_yn_17a', '42b_horzconst',
#        '53_single_panel_manufacturer',
#        'primary_roof_installation_date_44', '552aa_alrmcond',
#        '541_1a_pca', '53j_wiringevd', 'pca_reserve_desc_52b',
#        '552a_firealrm', '553aa_oscond', '53m_zinsco', '52r_vent_type',
#        'transformer_location_53ssbs', '552a_smokedet',
#        '442_was_ponding_observed', 'pca_reserve_yn_33a', '551f_piping',
#        '433_1e_pca', '552_fire_alarm_type', '541c_ceil1', '41c_walls',
#        'pca_reserve_yn_32a', '52ct1', '1a_summary_property_use',
#        'pca_reserve_yn_48a', '52ct4', '01zp_project_county',
#        '53ae_egcond', '441ap_flash_mat', '7q_accessibility',
#        '52o_temp_control', '52b_cs_cond', '52cbg2', '553_1a_pca',
#        '53aa_eleccond', '4za_roof_report_provided_1', '51d_wstobs',
#        '45_ext_str_hand', 'pca_reserve_yn_11a', '45b_extstr',
#        '431e_ptcond', '551_1a_pca', '52cl3', '51_1a_pca',
#        '01e_project_zip', 'pca_reserve_yn_37a',
#        '541c_last_load_test_date', '431f_sealcond', 'pca_reserve_yn_3a',
#        '52cbg5', '431_is_siding_painted_in_the_field',
#        'pca_reserve_yn_52a', 'pca_reserve_yn_9a', '53e_epanelloc',
#        '42c_roofconst', '51_water_heat_sto_tank_secured',
#        '1z_add_build_sum', '551_1d_pca', '541d_loc_insp_test_cert',
#        '42_1b_pca', '552c_panel', '541b_cap', 'pca_reserve_yn_18a',
#        '541d_panel1', 'pca_reserve_yn_46a', '551e_hose',
#        '1b_summary_acres', '432_1d_pca', '53n_emgen', 'pca_reserve_yn_6a',
#        '52d_cs_tr', '433x_primdoor_hardware', '431b_secfac',
#        'pca_reserve_yn_22a', '541e_elev_contractor', '431c_soffit',
#        '541f_last_cont_inspec_date', '431d_wallcond',
#        'pca_reserve_yn_56a', 'pca_reserve_yn_13a', 'pca_reserve_yn_49a',
#        '542_1a_pca', 'fire_extinguisher_location_551', '431_1c_pca',
#        '52za_is_there_hvac', 'pca_reserve_yn_35a', 'pca_reserve_yn_34a',
#        'are_there_other_systems_553', 'information_source_42', '52cbg3',
#        '53k_wiring', '552_1b_pca', '441_identify_party_who',
#        '441b_parapet', '52p_cost_table_type', '1u_summary_elev_1',
#        '01v_rm_last_name', '442c_rdraincond', '43m_cost_action_item',
#        '45y_int_str_guard', '01x_rm_email', '01n_client_address',
#        '1g_recent_capital', '441_1p_pca', '1y_summary_ada_parking',
#        '443_what_roof_mounted_items', '52b_pu_elec_quant',
#        '51_sewage_ejector_pumps', '1y_summary_van_parking',
#        '551i_fireext', '51m_cost_action_item', '01d_project_state',
#        '41a_source', '441a_primroof', '44m_cost_action_item',
#        '552h_alrminsp', '442b_draindest', '1j_summary_vert_cons',
#        '1s_summary_domrep_pipe', '01r_reviewer_first_name',
#        '42a_vertconst', '551j_fireext', '432b_windfrm', '51e_whdesc',
#        '441p_yn_sec_roof', '1k_summary_roof_deck', '433b_secdoor_hard',
#        '443_is_there_roof_mounted_equipment', '552d_panelloc',
#        '1k_summary_roof_frame', '01u_rm_first_name', '552e_monitor',
#        '1pp_summary_secroof2', '52q_acc_area_heat_type',
#        '441c_parapet_cond', '01g_report_date', '42g_frtp',
#        '01s_reviewer_last_name', '52b_ss_cond', '551d_pump',
#        'elevator_type_541', '45p_fireescapes_stairs_balconies',
#        '1d_summary_floor_num', '53_1a_pca', '52c_pu_elec_manu',
#        '53b_eserv', '441d_proofcond', '01b_project_address', '52d_pu_tr',
#        '551_hydrant_survcond', '1z_summary_beds',
#        '443_skylight_condition', '52a_packaged_unit_heat_source',
#        'primary_roof_type_44', '52f_pu_cai', '551r_fire_hydrant_loc',
#        '1eb_summary_ga_source', 'is_there_more_than_one_building_53',
#        '1d_any_reported_issues', '1t_summary_wiring',
#        '52m_cost_action_item', '01y_rm_phone', '01i_client_company',
#        '01a_project_name', '1m_summary_primfac', '41d_foundcond',
#        'describe_structural_issues_in_complete_sentences_42',
#        '1oo_summary_primroof2', '53l_gfci', '1z_summary_guestrooms',
#        '1i_planned_capital', '52g_pu_gas_manu', '51c_wstrep',
#        '42e_structcond', '01f_project_number', '51ab_conddesc',
#        'piping_information_source', '01o_client_city',
#        'area_served_by_water_heating_system_51', '01k_client_last_name',
#        '41b_const', '541g_elev3', '433ep_oh_door_equip', '1c_pre_survey',
#        '51p_cost_table_type', '1h_summary_const', '1e_summary_year_built',
#        '433a_primdoors', '51_site_seismic_zones', '441f_rfconddesc',
#        '443_roof_mounted_equipment_condition', '53_3a_pca',
#        '1ec_summary_nra_source', '54a_vertrans', '433c_doorcond',
#        '52b_pu_cond', '54m_cost_action_item',
#        'central_panel_manufacturer_552', '1v_summary_fire_prot',
#        '51af_probmatdesc', '51_domestic_water_booster', 'roof_framing_42',
#        'are_sprinkler_heads_present_551', '41p_cost_table_type',
#        '1z_summary_tenant_spaces', '441b_prim_cost_action_item',
#        'pca_reserve_yn_47a', '52f_pu_gas_quant', 'pca_reserve_yn_2a',
#        '52h_pu_gas_cap', 'pca_reserve_yn_39a', 'pca_reserve_yn_5a',
#        '1zp_build_const_date', '1b_overall_preventative_maintenance',
#        '433y_cost_table_type', '1y_summary_parking_area',
#        '433bp_oh_door_quant', '51bc_whtr', '441p_prim_warranty',
#        '45p_balc_insp', '551aa_suppcond', '51aa_cond', '51b_1b_pca',
#        'describe_facade_issues_in_complete_sentences_43', '433ap_oh_door',
#        '52c_pu_conddesc', 'secondary_roof_installation_date_44',
#        '53p_cost_table_type',
#        'are_the_multiple_structures_of_similar_construction',
#        'elevator_use_541', '53_distinct_electrical_wiring_types',
#        '1c_recent_capital_desc4', '43p_cost_table_type',
#        '1o_summary_primroof1', '441_was_roof_access_provided',
#        '52z_otr_sys_desc', '53c_eserv2', '52m_pu_gas_loc',
#        '1p_approx_parcel_summary', '551g_chemical', 'pca_reserve_yn_31a',
#        'pca_reserve_yn_10a', '1f_summary_gross_building', '52chp2',
#        '431p_sealant_conddesc', '2e_summary_gross_building_comment',
#        '52i_pu_gas_refridge', 'pca_reserve_yn_16a', 'pca_reserve_yn_24a',
#        '52_hvac_con_name', '53_2a_pca', '431a_primfac',
#        '4zb_roof_report_provided_2', 'pca_reserve_desc_53b',
#        'pca_reserve_yn_4a', '1g_summary_net_rentable',
#        '441_if_so_how_was_it_provided', '41_1a_pca',
#        '01s_client_number_include', '1a_recent_capital_desc2',
#        '42_distinct_frame_types', '1y_summary_total_parking',
#        '53_service_type', '52d_pu_elec_cap', '1a_overall_condition',
#        'pca_reserve_yn_25a', '433_distinct_door_types',
#        '1c_summary_building_num', 'pca_reserve_yn_20a',
#        'pca_reserve_desc_18b', 'where_is_the_chemical_tank_551',
#        'pca_reserve_yn_55a', '1ea_summary_yb_source', '51f_whdetail',
#        'pca_reserve_yn_7a', '1n_additional_investigations_desc',
#        '441bp_skylights', '52k_pu_elec_refridge', '01j_client_first_name',
#        '52d_uh_tr', '1f_capital_improvements', '1x_summary_alarm',
#        '441a_prim_cost_table_type',
#        'is_there_a_second_water_heating_system', '01t_reviewer_title',
#        '1z_summary_residential_units', '1jj_summary_hori_cons',
#        '1u_summary_elev_2', '442p_drain_conddesc', 'pca_reserve_yn_15a',
#        '52p_hvac_system', '51_distinct_water_heating_types',
#        '51ac_conddesc', '52d_ss_tr', '52fu3', '42p_cost_table_type',
#        '432w_cost_table_type', '552g_codet', '442w_cost_table_type',
#        'fire_protection_system_551', '45c_intstr', '541c_elevserve',
#        '433cp_oh_door_loc', '53_identify_service_amp_unit',
#        '541b_last_insp_date', '1h_recent_capital_desc',
#        '551w_cost_table_type', '1b_recent_capital_desc3', '01w_rm_title',
#        '1n_summary_secfac', '1i_summary_walls', '1z_summary_hvac',
#        '553y_cost_table_type', '441d_parapet_desc', '551ab_suppconddesc',
#        'describe_door_issues_in_complete_sentences_43',
#        '541ab_elevconddesc', '55p_cost_table_type', 'pca_reserve_yn_21a',
#        'pca_reserve_yn_51a', '52_distinct_hvac_types', '52b_hs_cond',
#        '551f_head', 'pca_reserve_yn_14a', '52d_hs_tr',
#        '443_skylight_conddesc', '4zc_roof_report_statement_1',
#        '551_1c_pca', '453_1h_pca', '541e_feat2',
#        '53b_multi_panel_manufacturer', '52ab_heatconddesc', '53g_eservmb',
#        '45z_int_str_hand', '553ab_osconddesc', '52cac4',
#        '431de_facade_ordinance_insp', '53f_eservmb',
#        '431_distinct_facade_types', '45a_frescp',
#        '442_choose_appropriate_ponding', '01m_client_salutation',
#        '542x_cost_action_item', '431m_facade_pt_conddesc',
#        '551c_fsuppwater', '1p_summary_secroof1', '52chp1',
#        'is_there_a_second_fire_suppression_system_551',
#        '441m_sec_warranty', '442_identify_the_locations', '52fu5',
#        '551ab_backflow_dev_loc', '52aa_heatcond', '454_1i_pca',
#        '552f_dialer', '541d_elev2', '51bb_whconddesc',
#        'describe_stair_fire_escape_andor_balcony_issues_in_complete_sen',
#        '52h_condens_ac_quant', '441c_secroof', '433b_secdoor',
#        'elevator_manufacture_2_541',
#        'amperage_supplied_to_first_switchgearpanel_53mbds',
#        '53ab_elecconddesc', '551_distinct_fire_extinguisher_types',
#        '52e_pu_elec_loc', '541a_elev', '452_1g_pca', 'pca_reserve_yn_38a',
#        'fire_pump_gallon_per_minute_capacity_551', 'pca_reserve_yn_53a',
#        'pca_reserve_desc_25b', '53h_eserv2mb', '53_multiple_service_amp',
#        '1a_additional_investigations_desc2', '551m_fire_ex_conddesc',
#        '52cac3', '541e_feat1', '1d_recent_capital_desc5',
#        '45p_cost_table_type', '551x_cost_action_item',
#        '01r_client_stamp_required', '441e_sroofcond',
#        '51_sewage_ejection_pump_condition',
#        '553_distinct_other_system_types', '52fu2',
#        'distinct_structure_types_41', '45d_intstrfin',
#        '1j_planned_capital_desc', '52b_pac_cond', '52f_ss_cai',
#        '53o_emgendesc', '52a_unit_heater_type', '52ms2',
#        'pca_reserve_desc_34b', '52ad_coolconddesc', '441cc_secroof',
#        '52ms3', 'describe_foundation_issues_in_complete_sentences_41',
#        '552ab_alrmconddesc', '441_distinct_roof_types',
#        '1u_summary_elev_3', '52b_uh_cond', '52ssc1', '541a_floor1',
#        '55m_cost_action_item', '1d_planned_capital_desc5',
#        '1k_recent_capital_desc', '1c_planned_capital_desc4', '52cac1',
#        'number_of_similar_elevators',
#        '443_roof_mounted_equipment_conddesc', '2k_summary_acres_comment',
#        '52cac2', '51_dom_water_sup_desc', '443_cost_table_type',
#        'number_of_escalators_542', '52h_hs_gas_cap',
#        'describe_window_issues_in_complete_sentences_43',
#        '52r_minisplit_quant', '52chp4',
#        '2h_summary_residential_units_comment', '53d_eserv3',
#        '541a_floor2', '51_distinct_piping_types', '54p_cost_table_type',
#        '1e_reported_issues_desc', '52ms1', '1m_recent_capital_desc',
#        '53_distinct_electrical_service_types',
#        '1pld_recent_capital_desc2', 'pca_reserve_desc_17b',
#        '1fw_auth_qual_exp', '45_ext_str_guard', '53h_eserv3mb',
#        '52d_pac_tr', '433z_cost_action_item',
#        '53_distinct_transformer_types', '2f_summary_net_rentable_comment',
#        '1zp_build_number_stories', 'pca_reserve_yn_41a',
#        'pca_reserve_yn_57a', '52i_hs_gas_loc', '52ae_hvactr',
#        '2d_summary_building_num_comment', '552_distinct_fire_alarm_types',
#        '52ct2', '551_distinct_fire_suppression_types',
#        'pca_reserve_yn_30a', 'pca_01_cost_threshhold_update',
#        'pca_reserve_desc_24b', '52cl5',
#        'amperage_supplied_to_main_switchgearpanel_53sbss',
#        '551l_suppserv2', '2g_summary_tenant_spaces_comment',
#        '52c_ss_conddesc', '1a_rec_cap_impr_pca', '52ac_coolcond',
#        '432_distinct_window_types', '52a_packaged_ac_type',
#        'is_there_a_third_water_heating_system', '52f_hs_cai',
#        '51_identify_rating_in_hp', '1plf_planned_capital_desc3',
#        '551m_suppwater2', '52chp3', '551n_pump2',
#        '1b_additional_investigations_desc3', 'pca_reserve_desc_22b',
#        '53_not_present_identify',
#        'amperage_supplied_to_main_switchgearpanel_53sbts',
#        '1p_planned_capital_desc', '1plb_planned_capital_desc3',
#        'pca_sus_conditions_cost_1a', '551z_fssdef_othr',
#        '453_distinct_int_stair_types', '53_ident_sngl_svc_amp_rate',
#        '1m_deviations2', '45e_balcconst', '51d_1d_pca',
#        '541_distinct_elevator_types', '52m_condens_hp_quant',
#        '1_irv_statement', '53i_epanellocmb', '52f_cs_cai',
#        'pca_reserve_desc_19b', '542aa_esccond', '1fy_auth_yr_exp',
#        '551q_suppinsp2', '52ce1', '52cbo1', '52g_hs_gas_manu',
#        'transformer_location_53mbds', '53_ident_lok_ob_fpe',
#        '51bd_whcond2', '553z_cost_action_item', '52f_pac_cai',
#        '1a_planned_capital_desc2', '52j_hs_gas_optemp', '1k_deviations',
#        '442x_cost_action_item', '51c_1c_pca', '52c_uh_conddesc',
#        'electric_motor_manufacturer_551', '1m_planned_capital_desc',
#        '1plb_recent_capital_desc2',
#        'amperage_supplied_to_main_switchgearpanel_53mbds3',
#        '551p_sprink2', '52cbg4', '52ct3', '52c_hs_conddesc',
#        '551_chemfiresup_conddesc', '51_sewage_ejector_pumps_number',
#        '551_ext_cost_table_type', '41f_distinct_foundation_types',
#        '51_dom_water_booster_pump', '52a_hydronic_boiler_type',
#        '541e_cap2', '441z_secroof_conddesc', '551_chemfiresup_survcond',
#        '52c_cs_conddesc', 'pca_reserve_desc_15b', 'pca_reserve_desc_32b',
#        '1n_recent_capital_desc', '551ac_suppcond2',
#        '52a_baseboard_heater_desc', '1fx_auth_cert_reg', '52ahu1',
#        '551_hydrant_conddesc', 'pca_reserve_desc_27b',
#        '4zd_roof_report_statement_2',
#        '1c_additional_investigations_desc4', 'pca_042_dock_doors',
#        'pca_reserve_yn_40a', 'electric_motor_horse_power_551',
#        'pca_reserve_yn_43a', 'pca_reserve_yn_42a', 'pca_reserve_yn_29a',
#        '52f_hs_gas_quant', '551_ext_cost_action_item', '51be_whcondesc2',
#        'amperage_supplied_to_main_switchgearpanel_53mbds2',
#        '51_identify_man_sewage_pumps', '432x_cost_action_item',
#        '45h_walkway', '51g_whdesc2', '52g_hs_oil_oppress',
#        '52b_packaged_ac_ptac_cap', '52k_hs_gas_oppress',
#        'pca_reserve_yn_28a', '1n_deviations3',
#        '1ple_recent_capital_desc2', '452_distinct_ext_stair_types',
#        'are_there_structures_present_on_the_subject_property',
#        '542ab_escconddesc', '541h_cap3', '53af_egconddesc',
#        '451_distinct_fire_escape_types', '541d_panel2',
#        'pca_reserve_desc_45b', '52c_hs_oil_manu', '51bf_whtr2',
#        '551_distinct_fire_hydrant_types', '541b_wall2',
#        '1plg_recent_capital_desc2', '52cl4', '52cl1', '1fz_auth_qual',
#        'number_of_similar_elevators_2_541', '1b_planned_capital_desc3',
#        '551_distinct_chemical_fire_suppression_types', '551k_supp2',
#        '2i_summary_guestrooms_comment', '454_distinct_balcony_types',
#        'elevator_type_2_541', '443_cost_action_item',
#        '1f_reported_issues_desc2', '1a_plan_cap_impr_pca',
#        '2j_summary_beds_comment', '541f_elevserve2',
#        'are_sprinkler_heads_present_2_551', '52c_pac_conddesc',
#        '1q_planned_capital_desc', '41m_cost_action_item',
#        'pca_reserve_desc_46b', '1plc_recent_capital_desc2',
#        '53m_cost_action_item', 'pca_reserve_desc_29b',
#        '51_cap_booster_pump', '1pla_recent_capital_desc2',
#        '42h_frtp_describe_non_deteriorated', '52cl2',
#        'pca_reserve_yn_27a', 'pca_reserve_desc_14b',
#        '1p_recent_capital_desc', 'pca_reserve_desc_13b',
#        '51_domestic_water_booster_number',
#        '1d_additional_investigations_desc5', '551ad_suppconddesc2',
#        'area_served_by_water_heating_system_2_51', 'pca_reserve_desc_16b',
#        '52d_beh_tr', '52e_hs_oil_loc', '51_identify_manu_booster_pumps',
#        '1u_summary_elev_5', '52az_climate_ctrl_units',
#        'pca_reserve_desc_23b', 'pca_reserve_desc_55b',
#        '1u_summary_elev_4', '01t_client_number', '52oth1',
#        '1o_recent_capital_desc', 'elevator_use_3_541',
#        'pca_reserve_yn_45a', '541c_ceil2', '52b_beh_cond',
#        'pca_reserve_desc_21b', '52cbo2', '541j_elev4', '51h_whdetail2',
#        '52fc1', '52fc2', '51_distinct_sewage_ejector_types',
#        'pca_reserve_desc_31b',
#        'is_there_more_than_one_main_electrical_service_53',
#        '1o_deviations4', '52ssoth1', 'electric_motor_manufacturer_2_551',
#        '541e_feat3', '1plh_planned_capital_desc3', '42m_cost_action_item',
#        '1fv_auth_title', '1pli_recent_capital_desc2',
#        'pca_reserve_desc_30b', '42f_frtp', '1r_planned_capital_desc',
#        '52hx1', '1plf_recent_capital_desc2', 'elevator_use_2_541',
#        'pca_reserve_yn_26a', '52hx2', '45m_cost_action_item',
#        '1pld_planned_capital_desc3',
#        '53_distinct_emergency_generator_types',
#        '51_dom_water_booster_pump_conddesc',
#        'are_all_portions_of_the_building_constructed_in_the_same_way',
#        '1pla_planned_capital_desc3', '1plh_recent_capital_desc2',
#        '52m_hvac_area_served', '1p_deviations5',
#        '1g_reported_issues_desc3', 'number_of_similar_elevators_3_541',
#        '52c_beh_conddesc', '551_hydrant_cost_table_type',
#        '52b_hs_oil_quant', '52d_hs_oil_cap', 'elevator_manufacture_3_541',
#        '551s_water_storage_loc', 'pca_reserve_desc_20b',
#        '1az_num_of_self_storage_units',
#        'electric_motor_horse_power_2_551', '52f_hs_oil_optemp',
#        '51_sewage_ejection_pump_conddesc', '52fu4',
#        '1_distinct_rec_cap_improvements', 'pca_reserve_desc_26b',
#        'pca_reserve_desc_28b', '552_distinct_smoke_detector_types',
#        '1plc_planned_capital_desc3', 'elevator_type_3_541', '52cbo3',
#        'are_there_multiple_structures_on_the_subject_property',
#        '44p_cost_table_type', '52f_uh_cai', '01f_vsims_number',
#        '1plg_planned_capital_desc3', '542w_cost_table_type',
#        '553a_othrsys', '541i_elevserve3', '1ple_planned_capital_desc3',
#        '1bz_num_of_climate_control_ss', '1o_planned_capital_desc',
#        '52cbo4', '1plj_recent_capital_desc2', 'pca_reserve_desc_33b',
#        'fire_pump_gallon_per_minute_capacity_2_551',
#        'pca_reserve_desc_35b', 'pca_reserve_desc_56b',
#        '551_hydrant_cost_action_item'], dtype=object)

# %%
# All of the unique sections in our data
retail['section_reference'].unique()
# Out:
# array(['5.4.1', '5.4.2', '5.5.1', '1.0', '5.5.3', '5.5.2', '5.3', '4.3.1',
#        '1', '4.4.1', '4.5', '4.3.2', '5.1', '4.3.3', '4.4.2', '5.2',
#        '4.2', '4.3', '4.1', '4.4', '4.4.3', '5.4.1.3', '5.4', '5.3.2',
#        '5.1.2', '5.0', '5.4.1.2', '5.3.3', '1.6', '5.5.1.2', '5.1.3',
#        '4.5.3', '4.5.2', '4.5.1', '5.4.1.4'], dtype=object)

# %% [markdown]
# The attributes and sections align with our knowledge that we are working with attributes from sections 1 (exec), 4, and 5 of the Property Condition Assessment reports.

# %% [markdown]
# <hr>

# %% [markdown]
# ### Looking at the unique values of id

# %% [markdown]
# We are presuming id is distinct for each row as we believe it represents the id for the specific attribute input for a given property.

# %%
# Count the number of unique values in id
retail['id'].nunique()
# Out:
# 558417

# %% [markdown]
# There are 558417 unique id's in the data set. This confirms that id is unique to each row. We will drop this column as it will not be useful to our analysis.

# %% [markdown]
# <hr>

# %% [markdown]
# ### Looking at the unique value of project_id

# %%
# Count the number of unique values in project_id (the property)
retail['project_id'].nunique()
# Out:
# 2891

# %%
# Count the number of occurrences for each unique value in project_id
retail['project_id'].value_counts()
# Out:
# project_id
# 564120    475
# 377788    337
# 559307    335
# 571408    315
# 593867    295
#          ...
# 356705     22
# 341562     21
# 618136     20
# 621305     20
# 621170     20
# Name: count, Length: 2891, dtype: int64

# %% [markdown]
# There is a total of 2891 unique projects. Not every project_id has the same number of attributes associated with it. We don't know if this is due to some PCA reports not being completely filled out, but we can proceed to isolate the attributes we'd like to examine.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Simplifying RETAIL data

# %% [markdown]
# We are simplifying RETAIL to just include the project_id, document_spot, and the_data columns.

# %%
# Simplify RETAIL
retail_simplified = retail[['project_id', 'document_spot', 'the_data']]
retail_simplified
# Out:
#         project_id        document_spot  \
# 0           621709           541b_wall1
# 1           621709             542a_esc
# 2           621709    551_fire_hydrants
# 3           621709    pca_reserve_yn_8a
# 4           623951     553b_othrsysdesc
# ...            ...                  ...
# 558412      609229          53m_stablok
# 558413      609647      441ap_flash_mat
# 558414      609229   pca_reserve_yn_13a
# 558415      609229  01zp_project_county
# 558416      609647        433ap_oh_door
#
#                                                  the_data
# 0                                               ["Metal"]
# 1                                                     yes
# 2                                                     yes
# 3                                                      no
# 4       Emergency lighting was typically provided by c...
# ...                                                   ...
# 558412                                               none
# 558413                    ["Similar to roofing membrane"]
# 558414                                                 no
# 558415                                             Sussex
# 558416                            ["Steel panel roll-up"]
#
# [558417 rows x 3 columns]

# %% [markdown]
# <hr>

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# LEGEND

# %% [markdown]
# document_spot: the variable name according to the PCA report

# %% [markdown]
# the_data: the input data

# %% [markdown]
# project_id: unique id for the property

# %% [markdown]
# ## Looking at the number of buildings per PCA report

# %% [markdown]
# If the number of buildings (1c_summary_building_number) is greater than 1, we can remove from our analysis.

# %%
# What are the unique value that could be inputted for 1c_summary_building_num
retail_simplified[retail_simplified['document_spot'] == '1c_summary_building_num']['the_data'].unique()
# Out:
# array(['2', '5', '1', '8', 'Five and one under construction', '3', '4',
#        '6', '13', '20', '7', 'One (1)',
#        '13 (includes five ground lease buildings which were not assessed)',
#        '11', 'One (w/ One Storage Garage)', '15', '9',
#        'Two (Buildings 1 through 6 are adjoining; Building 7 is stand-along)',
#        '10', 'One', '14', '21', '0', '33', 'Four', '25',
#        'Seven including three land lease buildings', 'Three',
#        'Three + Jungle Plaza', '16'], dtype=object)

# %% [markdown]
# We only want the buildings with 'One' and '1' in the input.

# %%
# Looking at the project_id's that have multiple buildings
multiple_buildings = retail_simplified[(retail_simplified['document_spot'] == '1c_summary_building_num') & 
                                        (retail_simplified['the_data'] > '1')]
multiple_buildings
# Out:
#         project_id            document_spot                         the_data
# 745         580845  1c_summary_building_num                                2
# 934         457720  1c_summary_building_num                                5
# 1123        398107  1c_summary_building_num                                8
# 1968        445385  1c_summary_building_num                                2
# 2560        381397  1c_summary_building_num  Five and one under construction
# ...            ...                      ...                              ...
# 552093      480322  1c_summary_building_num                                4
# 552126      479702  1c_summary_building_num                                5
# 552719      455381  1c_summary_building_num                               16
# 555290      488072  1c_summary_building_num                                2
# 555515      580834  1c_summary_building_num                                4
#
# [693 rows x 3 columns]

# %%
# Checking if we filtered correctly
multiple_buildings['the_data'].unique()
# Out:
# array(['2', '5', '8', 'Five and one under construction', '3', '4', '6',
#        '13', '20', '7', 'One (1)',
#        '13 (includes five ground lease buildings which were not assessed)',
#        '11', 'One (w/ One Storage Garage)', '15', '9',
#        'Two (Buildings 1 through 6 are adjoining; Building 7 is stand-along)',
#        '10', 'One', '14', '21', '33', 'Four', '25',
#        'Seven including three land lease buildings', 'Three',
#        'Three + Jungle Plaza', '16'], dtype=object)

# %% [markdown]
# There are still properties here with 'One', which means they only have one building. We want to exclude that.

# %%
# Exclude properties that have 'One' building
multiple_buildings2 = multiple_buildings[~multiple_buildings['the_data'].str.contains('One')]

multiple_buildings2
# Out:
#         project_id            document_spot                         the_data
# 745         580845  1c_summary_building_num                                2
# 934         457720  1c_summary_building_num                                5
# 1123        398107  1c_summary_building_num                                8
# 1968        445385  1c_summary_building_num                                2
# 2560        381397  1c_summary_building_num  Five and one under construction
# ...            ...                      ...                              ...
# 552093      480322  1c_summary_building_num                                4
# 552126      479702  1c_summary_building_num                                5
# 552719      455381  1c_summary_building_num                               16
# 555290      488072  1c_summary_building_num                                2
# 555515      580834  1c_summary_building_num                                4
#
# [685 rows x 3 columns]

# %% [markdown]
# ### Dropping properties with multiple buildings

# %%
# The unique properties with multiple buildings
drop_properties = multiple_buildings2['project_id'].unique()
# Number of properties we need to drop
len(drop_properties)
# Out:
# 685

# %% [markdown]
# Dropping the buildings from retail_simplified with the same project_id in drop_properties.

# %%
# Dropping rows from retail_simiplified that have the same project_id in drop_properties
retail_simplified = retail_simplified[~retail_simplified['project_id'].isin(drop_properties)]
retail_simplified['project_id'].nunique()
# Out:
# 2206

# %% [markdown]
# retail_simplified is now clean!

# %% [markdown]
# ### Exporting retail_simplified

# %%
# Export retail_simplified to folder
retail_simplified.to_csv('Clean Retail Data/retail_simple.csv', index=False)

# %% [markdown]
# <hr>

# %% [markdown]
# ### Dropping duplicate rows (project_id, document_spot, the_data)

# %%
retail_simplified = retail_simplified.drop_duplicates(subset=['project_id', 'document_spot', 'the_data'])

# %% [markdown]
# <hr>

# %% [markdown]
# ## Examining Retail analysis attributes

# %% [markdown]
# We want to see if there are properties with multiple inputs for the same attribute. We are going to look at the unique number of project_id's for the following attributes

# %% [markdown]
# - zipcode (01e_project_zip)

# %% [markdown]
# - square footage (1f_summary_gross_building)

# %% [markdown]
# - construction (42a_vertconst, 42b_horzconst)

# %% [markdown]
# ### Zipcodes

# %%
# Looking at the unique number of project_id for zip code attributes in retail_simplified
zipcodes = retail_simplified[retail_simplified['document_spot'] == '01e_project_zip']
num_zip = len(zipcodes)
uniq_zip = zipcodes['project_id'].nunique()
print('Number of zipcode attributes: ', num_zip)
print('Number of properties with zipcodes: ', uniq_zip)
# Out:
# Number of zipcode attributes:  2205
# Number of properties with zipcodes:  2205

# %% [markdown]
# There is no property with multiple zipcode attributes.

# %% [markdown]
# ### Looking for odd zipcodes

# %% [markdown]
# Zipcodes must satisfy the following

# %% [markdown]
# - 5 digits long

# %% [markdown]
# - Digits only

# %%
# Finding the rows with non-numeric zipcodes
not_all_digits = zipcodes[zipcodes['the_data'].str.contains('[a-zA-Z]')]
not_all_digits
# Out:
#         project_id    document_spot the_data
# 205929      472606  01e_project_zip  V7J 2C4

# %%
# Finding the rows with zipcodes that is not 5 digits
not_5_digits = zipcodes[zipcodes['the_data'].str.len() != 5]
not_5_digits
# Out:
#         project_id    document_spot    the_data
# 51945       248443  01e_project_zip        6320
# 205929      472606  01e_project_zip     V7J 2C4
# 314345      318910  01e_project_zip     85295
# 438871      441205  01e_project_zip  48038-3503
# 462112      258978  01e_project_zip        7960

# %% [markdown]
# There are 5 zipcodes that do not have 5 digits. Of them, project_ids 472606, 258978, and 248443 can be removed as it does not meet the zipcode guidelines. As for the rest, it seems to be a clerical issue which we can manually resolve.

# %%
# Just taking out the first 5 digits
drop_properties_full = not_5_digits['project_id']
drop_properties = [472606, 258978, 248443]
not_5_digits = not_5_digits[~not_5_digits['project_id'].isin(drop_properties)]

not_5_digits.loc[:, 'the_data'] = not_5_digits['the_data'].str[:5]
not_5_digits
# Out:
#         project_id    document_spot the_data
# 314345      318910  01e_project_zip    85295
# 438871      441205  01e_project_zip    48038

# %%
# Removing the faulty properties
zipcodes = zipcodes[~zipcodes['project_id'].isin(drop_properties_full)]

# %%
# Concatenating the fixed zipcodes
zipcodes = pd.concat([zipcodes, not_5_digits], ignore_index=True)

zipcodes
# Out:
#       project_id    document_spot the_data
# 0         621170  01e_project_zip    94114
# 1         402102  01e_project_zip    06902
# 2         409030  01e_project_zip    33624
# 3         376933  01e_project_zip    92672
# 4         507879  01e_project_zip    78207
# ...          ...              ...      ...
# 2197      339630  01e_project_zip    91367
# 2198      379235  01e_project_zip    27284
# 2199      332265  01e_project_zip    75062
# 2200      318910  01e_project_zip    85295
# 2201      441205  01e_project_zip    48038
#
# [2202 rows x 3 columns]

# %% [markdown]
# Double-checking !

# %%
# Looking at the unique number of project_id for zip code attributes in retail_simplified
num_zip = len(zipcodes)
uniq_zip = zipcodes['project_id'].nunique()
print('Number of zipcode attributes: ', num_zip)
print('Number of properties with zipcodes: ', uniq_zip)
# Out:
# Number of zipcode attributes:  2202
# Number of properties with zipcodes:  2202

# %% [markdown]
# <hr>

# %% [markdown]
# ### Sqft

# %%
# Looking at the unique number of project_id for square foot attributes in retail_simplified
sq_foots = retail_simplified[retail_simplified['document_spot'] == '1f_summary_gross_building']
num_sf = len(sq_foots)
uniq_sf = sq_foots['project_id'].nunique()
print('Number of square foot attributes: ', num_sf)
print('Number of properties with square footage: ', uniq_sf)
# Out:
# Number of square foot attributes:  2186
# Number of properties with square footage:  2186

# %%
sq_foots['the_data'].unique()
# Out:
# array(['2000', '9984', '10640', ..., '4,057 (Tax assessor)', '6,750',
#        '23,447 SF'], dtype=object)

# %% [markdown]
# Looking at this data, we can see that some of the sqft's have commas and text in them, while others do not (are just a sequence of numbers). We will remove the commas and just extract the digits to transform the sqft column to be an integer type. There are also na values that we need to omit.

# %%
# Remove NA's
sq_foots = sq_foots.dropna(subset=['the_data'])

# Replace commas and extract digits 
sq_foots['the_data'] = sq_foots['the_data'].str.replace(',', '')
sq_foots['the_data'] = sq_foots['the_data'].str.extract('(\d+)')

# Remove NA's
sq_foots = sq_foots.dropna(subset=['the_data'])

# Transform column to integers
sq_foots['the_data'] = sq_foots['the_data'].astype(float).astype(int)

# %%
sq_foots
# Out:
#         project_id              document_spot  the_data
# 562         494184  1f_summary_gross_building      2000
# 587         576666  1f_summary_gross_building      9984
# 1008        577861  1f_summary_gross_building     10640
# 1869        427876  1f_summary_gross_building      5000
# 2418        357520  1f_summary_gross_building     10282
# ...            ...                        ...       ...
# 557395      317124  1f_summary_gross_building     44049
# 557685      387690  1f_summary_gross_building     20354
# 557711      357629  1f_summary_gross_building      4057
# 557938      414286  1f_summary_gross_building      6750
# 558018      341545  1f_summary_gross_building     23447
#
# [2172 rows x 3 columns]

# %% [markdown]
# Great! Now our data is all clean.

# %% [markdown]
# ### Visualizing SQFT

# %%
DeepnoteChart(sq_foots, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#2266D3","tooltip":true},"encoding":{"x":{"bin":{"maxbins":50},"axis":{"title":"SQFT"},"sort":null,"type":"quantitative","field":"the_data"},"y":{"axis":{"title":"Count"},"sort":null,"type":"quantitative","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"count","formatType":"numberFormatFromNumberType"}}}]}],"title":"Histogram for SQFT","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"aditionalTypeInfo":{"histogramLayerIndexes":[0]},"tooltipDefaultMode":true}}""")

# %%
DeepnoteChart(sq_foots, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#2266D3","tooltip":true},"encoding":{"x":{"bin":{"maxbins":25},"axis":{"title":"SQFT"},"sort":null,"type":"quantitative","field":"the_data"},"y":{"axis":{"title":"Count"},"sort":null,"type":"quantitative","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"count","formatType":"numberFormatFromNumberType"}}}]}],"title":"Histogram of SQFT < 50000","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"aditionalTypeInfo":{"histogramLayerIndexes":[0]},"tooltipDefaultMode":true}}""")

# %% [markdown]
# The data is very skewed to the right.

# %% [markdown]
# <hr>

# %% [markdown]
# ### Construction

# %%
# Looking at the unique number of project_id for construction attributes in retail_simplified
# Vertical Constructions
vert_consts = retail_simplified[retail_simplified['document_spot'] == '42a_vertconst']
num_vc = len(vert_consts)
uniq_vc = vert_consts['project_id'].nunique()

print('Number of vertical constructions: ', num_vc)
print('Number of properties with vertical constructions: ', uniq_vc)

# Horizontal Constructions
horz_consts = retail_simplified[retail_simplified['document_spot'] == '42b_horzconst']
num_hc = len(horz_consts)
uniq_hc = horz_consts['project_id'].nunique()

print('Number of horizontal constructions: ', num_hc)
print('Number of properties with horizontal constructions: ', uniq_hc)

# Roof Constructions
horz_consts = retail_simplified[retail_simplified['document_spot'] == '42b_horzconst']
num_hc = len(horz_consts)
uniq_hc = horz_consts['project_id'].nunique()

print('Number of horizontal constructions: ', num_hc)
print('Number of properties with horizontal constructions: ', uniq_hc)
# Out:
# Number of vertical constructions:  2086
# Number of properties with vertical constructions:  2086
# Number of horizontal constructions:  1674
# Number of properties with horizontal constructions:  1674
# Number of horizontal constructions:  1674
# Number of properties with horizontal constructions:  1674

# %% [markdown]
# Based on the number of unique properties for each attribute, there is no overlap.

# %% [markdown]
# ### Examining unique values

# %%
vert_consts['the_data'].unique()
# Out:
# array(['["Steel-framed"]',
#        '["Conventional steel framing, isolated CMU, steel stud partition framing"]',
#        '["Conventional wood stud platform with isolated CMU"]',
#        '["Pre-engineered steel structure"]',
#        '["Pre-engineered steel structure", "Conventional steel framing, isolated CMU, steel stud partition framing"]',
#        '["Precast concrete wall panels, concrete columns, steel stud partition framing"]',
#        '["CMU load bearing walls, steel columns, steel stud partition framing"]',
#        '["Masonry wythe bearing walls, steel columns, steel stud partition framing"]',
#        '["Light-gauge steel studs, CMU center core"]',
#        '["Conventional wood stud platform"]',
#        '["Tilt-up concrete walls & CIP columns, steel stud framing"]',
#        '["CMU load-bearing exterior wall, concrete columns, steel stud partition framing"]',
#        '["Concrete masonry unit load bearing walls with interior steel columns"]',
#        '["Wood-framed"]',
#        '["CMU load bearing walls, steel columns, steel stud partition framing", "Other", ""]',
#        '["Concrete masonry unit load bearing walls with interior steel columns", "Steel-framed"]',
#        '["Precast concrete walls & columns, steel stud framing"]',
#        '["Other", "Concrete masonry units (CMU)"]',
#        '["Concrete tilt-up perimeter walls"]',
#        '["Cast-in-place concrete"]',
#        '["Concrete tilt-up perimeter walls with interior steel columns"]',
#        '["Cast-in-place exterior concrete walls & interior columns, steel stud partition framing"]',
#        '["Wood post-and-beam framing, wood stud framing"]',
#        '["Steel-framed", "Pre-fab metal"]',
#        '["Precast concrete wall panels, steel columns, steel stud framing", "Tilt-up concrete walls & CIP columns, steel stud framing"]',
#        '["Concrete tilt-up perimeter walls", "Concrete masonry unit load bearing walls with interior steel columns"]',
#        '["Wood-framed", "Light-gauge steel"]',
#        '["Precast concrete wall panels, steel columns, steel stud framing"]',
#        '["Wood-framed", "Steel-framed"]',
#        '["Conventional wood stud platform", "Wood post-and-beam framing, wood stud framing"]',
#        '["Concrete masonry unit load bearing walls with steel framing"]',
#        '["Pre-fab metal"]',
#        '["Conventional steel framing, isolated CMU, steel stud partition framing", "Wood post-and-beam framing, wood stud framing"]',
#        '["Cast-in-place concrete", "Other", "with CMU"]',
#        '["Concrete masonry unit load bearing walls with steel framing", "Light-gauge steel"]',
#        '["Precast concrete"]',
#        '["Other", "concrete masonry unit (CMU) perimeter walls with interior steel columns and CMU walls"]',
#        '["Concrete masonry unit load bearing walls with interior steel columns", "Light-gauge steel"]',
#        '["Conventional steel framing, isolated CMU, steel stud partition framing", "Conventional wood stud platform with isolated CMU"]',
#        '["Cast-in-place concrete", "Steel-framed"]',
#        '["CMU load bearing walls, steel columns, steel stud partition framing", "Conventional wood stud platform with isolated CMU"]',
#        '["Concrete masonry unit load bearing walls with interior steel columns", "Pre-fab metal"]',
#        '["CMU load-bearing exterior wall, concrete columns, steel stud partition framing", "Light-gauge steel studs, CMU center core"]',
#        '["Other", "brick masonry"]',
#        '["Steel-framed", "Light-gauge steel"]',
#        '["Light-gauge steel studs, CMU center core", "Wood post-and-beam framing, wood stud framing"]',
#        '["Other", "Cast-in place reinforced concrete perimeter bearing walls"]',
#        '["Concrete masonry unit load bearing walls with interior steel columns", "Wood-framed"]',
#        '["CMU load bearing walls, steel columns, steel stud partition framing", "Wood post-and-beam framing, wood stud framing"]',
#        '["Cast-in-place exterior concrete walls & interior columns, steel stud partition framing", "CMU load bearing walls, steel columns, steel stud partition framing"]',
#        '["Other", "Conventional steel framing, isolated CMU, steel stud partition framing"]',
#        '["Cast-in-place concrete", "Concrete masonry unit load bearing walls with interior steel columns", "Wood-framed"]',
#        '["Concrete tilt-up perimeter walls with interior steel columns", "Concrete masonry unit load bearing walls with interior steel columns"]',
#        '["Conventional steel framing, isolated CMU, steel stud partition framing", "Light-gauge steel studs, CMU center core"]',
#        '["Light-gauge steel"]',
#        '["Cast-in-place concrete", "Wood-framed"]',
#        '["Concrete tilt-up perimeter walls with interior steel columns", "Wood-framed"]',
#        '["Precast concrete wall panels, concrete columns, steel stud partition framing", "CMU load-bearing exterior wall, concrete columns, steel stud partition framing"]',
#        '["Precast concrete wall panels, steel columns, steel stud framing", "Masonry wythe bearing walls, steel columns, steel stud partition framing"]',
#        '["Wood-framed", "Steel-framed", "Light-gauge steel"]',
#        '["Concrete masonry unit load bearing walls with interior steel columns", "Other", "load bearing brick"]',
#        '["CMU load bearing walls, steel columns, steel stud partition framing", "CMU load-bearing exterior wall, concrete columns, steel stud partition framing", "Conventional steel framing, isolated CMU, steel stud partition framing"]',
#        '["CMU load-bearing exterior wall, concrete columns, steel stud partition framing", "Conventional steel framing, isolated CMU, steel stud partition framing"]',
#        '["Cast-in-place concrete", "Concrete masonry unit load bearing walls with interior steel columns", "Wood-framed", "Steel-framed"]',
#        '["Steel-framed", "Other", "load-bearing concrete masonry unit (CMU) walls"]',
#        '["Concrete tilt-up perimeter walls", "Steel-framed"]',
#        '["CMU load bearing walls, steel columns, steel stud partition framing", "Light-gauge steel studs, CMU center core"]',
#        '["Other", "pre-engineered rigid steel framing system"]',
#        '["Cast-in-place concrete", "Concrete masonry unit load bearing walls with interior steel columns", "Steel-framed"]',
#        '["Cast-in-place exterior concrete walls & interior columns, steel stud partition framing", "CMU load-bearing exterior wall, concrete columns, steel stud partition framing"]',
#        '["Precast concrete", "Steel-framed"]',
#        '["Concrete masonry unit load bearing walls with interior steel columns", "Other", ". Interior partition walls were framed with light-gauge steel studs. "]',
#        '["Concrete tilt-up perimeter walls", "Concrete tilt-up perimeter walls with interior steel columns", "Concrete masonry unit load bearing walls with interior steel columns", "Wood-framed", "Steel-framed"]',
#        '["Other", "conventional steel framing consisting of steel columns generally on a grid around the perimeter and at interior load-bearing locations. Interior and partition walls were framed with light-gauge steel studs."]',
#        '["Concrete tilt-up perimeter walls", "Wood-framed"]',
#        '["Concrete masonry unit load bearing walls with interior steel columns", "Steel-framed", "Light-gauge steel"]',
#        '["Other", "Masonry brick load bearing"]',
#        '["Other", "Reinforced masonry bearing/ shear walls and steel columns"]',
#        '["CMU load bearing walls, steel columns, steel stud partition framing", "Masonry wythe bearing walls, steel columns, steel stud partition framing"]',
#        '["Cast-in-place concrete", "Concrete masonry unit load bearing walls with interior steel columns"]',
#        '["Other", "Reinforced masonry perimeter bearing walls with cast-in-place reinforced concrete beams and columns"]',
#        '["Wood-framed", "Steel-framed", "Other", "brick masonry"]',
#        '["Other", "Retrofitted masonry bearing walls"]',
#        '["Conventional steel framing, isolated CMU, steel stud partition framing", "Conventional wood stud platform"]',
#        '["Other", "steel-reinforced concrete framing"]',
#        '["Steel-framed", "Other", "with sections of concrete masonry unit (CMU) walls"]',
#        '["Other", "post and beam"]',
#        '["CMU load bearing walls, steel columns, steel stud partition framing", "Conventional steel framing, isolated CMU, steel stud partition framing"]',
#        '["Other", "Masonry construction with steel interior supports"]',
#        '["Precast concrete wall panels, steel columns, steel stud framing", "CMU load bearing walls, steel columns, steel stud partition framing"]',
#        '["CMU load-bearing exterior wall, concrete columns, steel stud partition framing", "Conventional wood stud platform"]',
#        '["Tilt-up concrete walls & CIP columns, steel stud framing", "CMU load bearing walls, steel columns, steel stud partition framing"]',
#        '["Other", "rigid steel framing"]'], dtype=object)

# %%
horz_consts['the_data'].unique()
# Out:
# array(['["No upper floors present"]',
#        '["Wood-framing with wood decking"]',
#        '["Cast-in-place concrete with post tension concrete slabs"]',
#        '["Wood-framing with wood decking and concrete topping"]',
#        '["Conventional wood frame and wood decking "]',
#        '["Steel-framed with steel decking"]',
#        '["Mezzanine: Steel-framed and metal grating"]',
#        '["Precast concrete T\'s"]',
#        '["Steel-framed with steel decking and concrete topping"]',
#        '["Open-web steel joists and metal decking with concrete fill"]',
#        '["Prefabricated wood trusses and plywood decking"]',
#        '["Conventional steel frame and metal deck with concrete fill"]',
#        '["Cast-in-place concrete with concrete decking", "Conventional steel frame and metal deck with concrete fill"]',
#        '["Cast-in-place concrete with concrete decking"]',
#        '["Open-web steel joists with steel decking"]',
#        '["Wood plank-and-beam framing"]',
#        '["Precast concrete with concrete decking"]',
#        '["No upper floors present", "Open-web steel joists with steel decking"]',
#        '["Light-gauge steel and metal decking with concrete fill"]',
#        '["Wood-framing with wood decking", "Steel-framed with steel decking and concrete topping"]',
#        '["Other", "a mezzanine level located at the southeast corner of the structure. "]',
#        '["Light-gauge steel and wood panel subflooring"]',
#        '["Mezzanine: Steel-framed and metal grating", "Conventional wood frame and wood decking "]',
#        '["Conventional wood frame and wood decking ", "Light-gauge steel and wood panel subflooring"]',
#        '["Open-web steel joists with precast decking"]',
#        '["Other", "Wood built back-of-house mezzanine area"]',
#        '["Mezzanine: Steel-framed and metal grating", "Light-gauge steel and metal decking with concrete fill"]',
#        '["Other"]',
#        '["Precast concrete T\'s", "Conventional steel frame and metal deck with concrete fill"]',
#        '["Steel-framed with steel decking and concrete topping", "Open-web steel joists with steel decking"]',
#        '["Wood-framing with wood decking and concrete topping", "Steel-framed with steel decking"]',
#        '["Open-web steel joists and metal decking with concrete fill", "Conventional wood frame and wood decking "]',
#        '["Cast-in-place concrete with concrete decking", "Wood plank-and-beam framing"]',
#        '["Conventional steel frame and metal deck with concrete fill", "Open-web steel joists and metal decking with concrete fill"]',
#        '["Wood-framing with wood decking", "Open-web steel joists with steel decking"]',
#        '["No upper floors present", "Cast-in-place concrete with concrete decking"]',
#        '["Other", "upper mezzanine levels consisted of finished ceiling. The Horizontal floor system was undetermined at the time of this report."]',
#        '["No upper floors present", "Wood-framing with wood decking and concrete topping", "Wood-framing with wood decking", "Steel-framed with steel decking", "Steel-framed with steel decking and concrete topping", "Open-web steel joists with steel decking"]',
#        '["Conventional steel frame and metal deck with concrete fill", "Open-web steel joists and metal decking with concrete fill", "Prefabricated wood trusses and plywood decking"]',
#        '["Open-web steel joists with steel decking", "Precast concrete with concrete decking"]'],
#       dtype=object)

# %% [markdown]
# <hr>

# %% [markdown]
# ## Exporting individual data files

# %% [markdown]
# ### Zip codes

# %%
# Using our zipcodes df from earlier to create a flipped 
# dataframe for just zipcodes
zipcodes = zipcodes.drop(columns=['document_spot'])
zipcodes = zipcodes.rename(columns={'the_data': 'zipcode'})

# %% [markdown]
# Exporting our clean data to Clean Retail Data (below)

# %%
# Export zipcodes to folder
zipcodes.to_csv('Clean Retail Data/retail_zipcodes.csv', index=False)

# %% [markdown]
# <hr>

# %% [markdown]
# ### Sqft

# %%
# Using our sq_foots df from earlier to create a flipped
# dataframe for just square feet inputs
sq_foots = sq_foots.drop(columns=['document_spot'])
sq_foots = sq_foots.rename(columns={'the_data': 'sqft'})

# %% [markdown]
# Exporting our clean data to Clean Retail Data (below)

# %%
# Export sq_foots to folder
sq_foots.to_csv('Clean Retail Data/retail_sqfts.csv', index=False)

# %% [markdown]
# <hr>

# %% [markdown]
# ### Vertical Const & Horizontal Const & Roof Frame

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=aa72ad5b-4609-409b-ae7e-8a5fd2e73142' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
